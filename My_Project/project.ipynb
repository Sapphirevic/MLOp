# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as ans
import warnings
warnings.filterwarnings('ignore')

# %%
lab = pd.read_csv('jobs_in_data.csv')

# %%
selected_rows = lab[lab['job_title'] == 'Data Architect']
selected_rows.head(10)
# Out:
#      work_year       job_title                    job_category  \
# 1         2023  Data Architect  Data Architecture and Modeling
# 2         2023  Data Architect  Data Architecture and Modeling
# 156       2023  Data Architect  Data Architecture and Modeling
# 157       2023  Data Architect  Data Architecture and Modeling
# 316       2023  Data Architect  Data Architecture and Modeling
# 317       2023  Data Architect  Data Architecture and Modeling
# 374       2023  Data Architect  Data Architecture and Modeling
# 375       2023  Data Architect  Data Architecture and Modeling
# 409       2023  Data Architect  Data Architecture and Modeling
# 410       2023  Data Architect  Data Architecture and Modeling
#
#     salary_currency  salary  salary_in_usd employee_residence  \
# 1               USD  186000         186000      United States
# 2               USD   81800          81800      United States
# 156             USD  185000         185000      United States
# ...

# %%
lab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
lab.isnull().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
filtered_lab = lab[lab['work_year'] == 2022]
filtered_lab
# Out:
#       work_year                           job_title  \
# 915        2022                AI Research Engineer
# 2857       2022          Machine Learning Scientist
# 3108       2022  Applied Machine Learning Scientist
# 3221       2022                   Research Engineer
# 3683       2022     Business Intelligence Developer
# ...         ...                                 ...
# 9124       2022              Financial Data Analyst
# 9127       2022                       Data Engineer
# 9128       2022      Lead Machine Learning Engineer
# 9130       2022            Computer Vision Engineer
# 9133       2022                         ML Engineer
#
#                    job_category salary_currency  salary  salary_in_usd  \
# 915   Data Science and Research             GBP   30000          36940
# 2857    Machine Learning and AI             USD   80000          80000
# 3108    Machine Learning and AI             EUR   93000          97712
# ...

# %%
new_file = "jobs_in_data.2022"
filtered_lab.to_csv(new_file, index=False)
new_file
# Out:
# 'jobs_in_data.2022'

# %%
 new_1 = pd.read_csv('jobs_in_data.2022')
 new_1
# Out:
#       work_year                           job_title  \
# 0          2022                AI Research Engineer
# 1          2022          Machine Learning Scientist
# 2          2022  Applied Machine Learning Scientist
# 3          2022                   Research Engineer
# 4          2022     Business Intelligence Developer
# ...         ...                                 ...
# 1629       2022              Financial Data Analyst
# 1630       2022                       Data Engineer
# 1631       2022      Lead Machine Learning Engineer
# 1632       2022            Computer Vision Engineer
# 1633       2022                         ML Engineer
#
#                    job_category salary_currency  salary  salary_in_usd  \
# 0     Data Science and Research             GBP   30000          36940
# 1       Machine Learning and AI             USD   80000          80000
# 2       Machine Learning and AI             EUR   93000          97712
# ...

# %%
filtered = lab[lab['work_year'] == 2023]
filtered
# Out:
#       work_year                  job_title                    job_category  \
# 0          2023       Data DevOps Engineer                Data Engineering
# 1          2023             Data Architect  Data Architecture and Modeling
# 2          2023             Data Architect  Data Architecture and Modeling
# 3          2023             Data Scientist       Data Science and Research
# 4          2023             Data Scientist       Data Science and Research
# ...         ...                        ...                             ...
# 7492       2023  Machine Learning Engineer         Machine Learning and AI
# 7493       2023             Data Scientist       Data Science and Research
# 7494       2023             Data Scientist       Data Science and Research
# 7495       2023              Data Engineer                Data Engineering
# 7496       2023              Data Engineer                Data Engineering
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
new_file = "jobs_in_data.2023"
filtered.to_csv(new_file, index=False)
new_file
# Out:
# 'jobs_in_data.2023'

# %%
 new_2 = pd.read_csv('jobs_in_data.2023')
 new_2
# Out:
#       work_year                  job_title                    job_category  \
# 0          2023       Data DevOps Engineer                Data Engineering
# 1          2023             Data Architect  Data Architecture and Modeling
# 2          2023             Data Architect  Data Architecture and Modeling
# 3          2023             Data Scientist       Data Science and Research
# 4          2023             Data Scientist       Data Science and Research
# ...         ...                        ...                             ...
# 7448       2023  Machine Learning Engineer         Machine Learning and AI
# 7449       2023             Data Scientist       Data Science and Research
# 7450       2023             Data Scientist       Data Science and Research
# 7451       2023              Data Engineer                Data Engineering
# 7452       2023              Data Engineer                Data Engineering
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
filter = lab[lab['work_year'] == 2020]

# %%
new_file = "jobs_in_data.2020"
filter.to_csv(new_file, index=False)
new_file
# Out:
# 'jobs_in_data.2020'

# %%
 new_3 = pd.read_csv('jobs_in_data.2020')

# %%
filters = lab[lab['work_year'] == 2020]
filters
# Out:
#       work_year                       job_title               job_category  \
# 2086       2020             Azure Data Engineer           Data Engineering
# 2289       2020              Staff Data Analyst              Data Analysis
# 4115       2020            Staff Data Scientist  Data Science and Research
# 4592       2020                    Data Analyst              Data Analysis
# 4623       2020  Managing Director Data Science  Data Science and Research
# ...         ...                             ...                        ...
# 9344       2020                   Data Engineer           Data Engineering
# 9345       2020       Machine Learning Engineer    Machine Learning and AI
# 9351       2020                  Data Scientist  Data Science and Research
# 9353       2020                  Data Scientist  Data Science and Research
# 9354       2020           Business Data Analyst              Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
new_file = "jobs_in_data.2021"
filters.to_csv(new_file, index=False)
new_file
# Out:
# 'jobs_in_data.2021'

# %%
 new_4 = pd.read_csv('jobs_in_data.2021')
 new_4
# Out:
#     work_year                       job_title               job_category  \
# 0        2020             Azure Data Engineer           Data Engineering
# 1        2020              Staff Data Analyst              Data Analysis
# 2        2020            Staff Data Scientist  Data Science and Research
# 3        2020                    Data Analyst              Data Analysis
# 4        2020  Managing Director Data Science  Data Science and Research
# ..        ...                             ...                        ...
# 66       2020                   Data Engineer           Data Engineering
# 67       2020       Machine Learning Engineer    Machine Learning and AI
# 68       2020                  Data Scientist  Data Science and Research
# 69       2020                  Data Scientist  Data Science and Research
# 70       2020           Business Data Analyst              Data Analysis
#
#    salary_currency  salary  salary_in_usd employee_residence experience_level  \
# ...

# %%
 new_2_categ = new_2.select_dtypes(include=object)  # categ - categorical
 new_2_num = new_2.select_dtypes(np.number)
new_2_num
# Out:
#       work_year  salary  salary_in_usd
# 0          2023   88000          95012
# 1          2023  186000         186000
# 2          2023   81800          81800
# 3          2023  212000         212000
# 4          2023   93300          93300
# ...         ...     ...            ...
# 7448       2023  134500         134500
# 7449       2023  130000         130000
# 7450       2023   90000          90000
# 7451       2023  160000         160000
# 7452       2023  135000         135000
#
# [7453 rows x 3 columns]

# %%
new_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7453 entries, 0 to 7452
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           7453 non-null   int64
#  1   job_title           7453 non-null   object
#  2   job_category        7453 non-null   object
#  3   salary_currency     7453 non-null   object
#  4   salary              7453 non-null   int64
#  5   salary_in_usd       7453 non-null   int64
#  6   employee_residence  7453 non-null   object
#  7   experience_level    7453 non-null   object
#  8   employment_type     7453 non-null   object
#  9   work_setting        7453 non-null   object
#  10  company_location    7453 non-null   object
#  11  company_size        7453 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 698.8+ KB

# %%
plt.hist(new_2['wsalary_in_usd'], bins=20)
plt.xlabel('Salary_in_usd')
plt.ylabel('Frequency')
plt.title('Distribution of Work Year')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'wsalary_in_usd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ...

# %%
sns.boxplot(x='salary_in_', y='salary', data=new_2)
plt.xlabel('Salary Currency')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by Currency')
plt.show()
